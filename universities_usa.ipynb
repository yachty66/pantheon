# %%
#universities USA
"""
https://public.opendatasoft.com/explore/dataset/us-colleges-and-universities/table/?flg=en-us


need 6000 logos of universities in the USA. will create me an agent who will get them

what is the best way of creating an agent which is able to get all of those logos?

https://www.kaggle.com/datasets/sumithbhongale/american-university-data-ipeds-dataset

get the universities from the

"""
import pandas as pd

# Load the Excel file
df = pd.read_excel('IPEDS_data.xlsx', engine='openpyxl')

# Display the first few rows of the dataframe
print(df.head())
# Out:
#    ID number                                 Name  year    ZIP code  \
# 0     100654             Alabama A & M University  2013       35762
# 1     100663  University of Alabama at Birmingham  2013  35294-0110
# 2     100690                   Amridge University  2013  36117-3553
# 3     100706  University of Alabama in Huntsville  2013       35899
# 4     100724             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# ...

# %%
with open('columns.txt', 'w') as f:
    for col in df.columns.tolist():
        f.write(col + '\n')

# %%
#make a new dataset with less features
df = df[['Name', 'Longitude location of institution', 'Latitude location of institution']]
print(df.head())
# Write the DataFrame to a new CSV file
df.to_csv('new_universities_usa.csv', index=False)
# Out:
#                                   Name  Longitude location of institution  \
# 0             Alabama A & M University                         -86.568502
# 1  University of Alabama at Birmingham                         -86.809170
# 2                   Amridge University                         -86.174010
# 3  University of Alabama in Huntsville                         -86.638420
# 4             Alabama State University                         -86.295677
#
#    Latitude location of institution
# 0                         34.783368
# 1                         33.502230
# 2                         32.362609
# 3                         34.722818
# 4                         32.364317

# %%
#define list with search queries
import urllib.parse

# Assuming 'df' is your DataFrame containing the university names
search_queries = [
    f"http://api.duckduckgo.com/?q={urllib.parse.quote_plus(name)}%20wikipedia&format=json"
    for name in df['Name'] 
]

# Add the search queries as a new column to the DataFrame
df['search_url'] = [
    f"http://api.duckduckgo.com/?q={urllib.parse.quote_plus(name)}%20wikipedia&format=json"
    for name in df['Name']
]

# Write the updated DataFrame to a new CSV file
df.to_csv('new_universities_usa.csv', index=False)

# %%
#next i want to get the url of the logo and website if available
# {
#   "Abstract": "Alabama Agricultural and Mechanical University is a public historically black land-grant university in Normal, Huntsville, Alabama. Founded in 1875, it took its present name in 1969. It was one of about 180 \"normal schools\" founded by state governments in the 19th century to train teachers for the rapidly growing public common schools. It was one of 23 established to train African Americans to teach in segregated schools. Some closed but most steadily expanded their role and became state colleges in the early 20th century and state universities in the late 20th century. AAMU is a member-school of the Thurgood Marshall College Fund and is accredited by the Southern Association of Colleges and Schools. Alabama Agricultural and Mechanical University Historic District, also known as Normal Hill College Historic District, has 28 buildings and four structures listed in the United States National Register of Historic Places.",
#   "AbstractSource": "Wikipedia",
#   "AbstractText": "Alabama Agricultural and Mechanical University is a public historically black land-grant university in Normal, Huntsville, Alabama. Founded in 1875, it took its present name in 1969. It was one of about 180 \"normal schools\" founded by state governments in the 19th century to train teachers for the rapidly growing public common schools. It was one of 23 established to train African Americans to teach in segregated schools. Some closed but most steadily expanded their role and became state colleges in the early 20th century and state universities in the late 20th century. AAMU is a member-school of the Thurgood Marshall College Fund and is accredited by the Southern Association of Colleges and Schools. Alabama Agricultural and Mechanical University Historic District, also known as Normal Hill College Historic District, has 28 buildings and four structures listed in the United States National Register of Historic Places.",
#   "AbstractURL": "https://en.wikipedia.org/wiki/Alabama_A%26M_University",
#   "Answer": "",
#   "AnswerType": "",
#   "Definition": "",
#   "DefinitionSource": "",
#   "DefinitionURL": "",
#   "Entity": "location",
#   "Heading": "Alabama A&M University",
#   "Image": "/i/81907f4fe3655524.png",
#   "ImageHeight": 270,
#   "ImageIsLogo": 1,
#   "ImageWidth": 618,
#   "Infobox": {
#     "content": [
#       {
#         "data_type": "string",
#         "label": "Former name",
#         "sort_order": "1000",
#         "value": "Huntsville State Normal School for Negroes (1875–1885), State Normal and Industrial School of Huntsville (1885–1896), The State Agricultural and Mechanical College for Negroes (1896–1919), State Agricultural and Mechanical Institute for Negroes (1919–1948), Alabama Agricultural and Mechanical College (1948–1969)",
#         "wiki_order": 0
#       },
#       {
#         "data_type": "string",
#         "label": "Motto",
#         "sort_order": "1001",
#         "value": "\"Service is Sovereignty\"",
#         "wiki_order": 1
#       },
#       {
#         "data_type": "string",
#         "label": "Type",
#         "sort_order": "1002",
#         "value": "Public historically black land-grant university",
#         "wiki_order": 2
#       },
#       {
#         "data_type": "string",
#         "label": "Established",
#         "sort_order": "2",
#         "value": "1875",
#         "wiki_order": 3
#       },
#       {
#         "data_type": "string",
#         "label": "Founder",
#         "sort_order": "1003",
#         "value": "William Hooper Councill",
#         "wiki_order": 4
#       },
#       {
#         "data_type": "string",
#         "label": "Academic affiliations",
#         "sort_order": "1004",
#         "value": "ACES, ORAU, Space-grant",
#         "wiki_order": 5
#       },
#       {
#         "data_type": "string",
#         "label": "Endowment",
#         "sort_order": "1005",
#         "value": "$48.0 million (2019)",
#         "wiki_order": 6
#       },
#       {
#         "data_type": "string",
#         "label": "President",
#         "sort_order": "3",
#         "value": "Daniel K. Wims",
#         "wiki_order": 7
#       },
#       {
#         "data_type": "string",
#         "label": "Students",
#         "sort_order": "2",
#         "value": "6,001 (Fall 2018)",
#         "wiki_order": 8
#       },
#       {
#         "data_type": "string",
#         "label": "Postgraduates",
#         "sort_order": "1006",
#         "value": "963 (Fall 2018)",
#         "wiki_order": 9
#       },
#       {
#         "data_type": "string",
#         "label": "Campus",
#         "sort_order": "1007",
#         "value": "Midsize city",
#         "wiki_order": 10
#       },
#       {
#         "data_type": "string",
#         "label": "Colors",
#         "sort_order": "1008",
#         "value": "Maroon, White",
#         "wiki_order": 11
#       },
#       {
#         "data_type": "string",
#         "label": "Mascot",
#         "sort_order": "3",
#         "value": "Butch",
#         "wiki_order": 12
#       },
#       {
#         "data_type": "string",
#         "label": "Sporting affiliations",
#         "sort_order": "1009",
#         "value": "NCAA Division I FCS – SWAC",
#         "wiki_order": 13
#       },
#       {
#         "data_type": "string",
#         "label": "Website",
#         "sort_order": "1010",
#         "value": "[www.aamu.edu]",
#         "wiki_order": 14
#       },
#       {
#         "data_type": "twitter_profile",
#         "label": "Twitter profile",
#         "value": "aamuedu",
#         "wiki_order": "102"
#       },
#       {
#         "data_type": "facebook_profile",
#         "label": "Facebook profile",
#         "value": "aamuedu",
#         "wiki_order": "104"
#       },
#       {
#         "data_type": "youtube_channel",
#         "label": "Youtube channel",
#         "value": "UCVJ5b4frvME83v1fbyBm7Tw",
#         "wiki_order": "105"
#       },
#       {
#         "data_type": "coordinates",
#         "label": "Coordinates",
#         "value": {
#           "altitude": null,
#           "globe": "http://www.wikidata.org/entity/Q2",
#           "latitude": 34.782611111111,
#           "longitude": -86.568694444444,
#           "precision": 0.000027777777777778
#         },
#         "wiki_order": "205"
#       },
#       {
#         "data_type": "instance",
#         "label": "Instance of",
#         "value": {
#           "entity-type": "item",
#           "id": "Q875538",
#           "numeric-id": 875538
#         },
#         "wiki_order": "207"
#       },
#       {
#         "data_type": "instance_2",
#         "label": "Instance of",
#         "value": {
#           "entity-type": "item",
#           "id": "Q615150",
#           "numeric-id": 615150
#         },
#         "wiki_order": "207"
#       },
#       {
#         "data_type": "instance_3",
#         "label": "Instance of",
#         "value": {
#           "entity-type": "item",
#           "id": "Q1620945",
#           "numeric-id": 1620945
#         },
#         "wiki_order": "207"
#       },
#       {
#         "data_type": "instance_4",
#         "label": "Instance of",
#         "value": {
#           "entity-type": "item",
#           "id": "Q23002039",
#           "numeric-id": 23002039
#         },
#         "wiki_order": "207"
#       },
#       {
#         "data_type": "official_website",
#         "label": "Official Website",
#         "value": "http://www.aamu.edu/",
#         "wiki_order": "208"
#       },
#       {
#         "data_type": "wd_description",
#         "label": "Wikidata description",
#         "value": "historically black land grant university",
#         "wiki_order": "210"
#       },
#       {
#         "data_type": "wikidata_id",
#         "label": "Wikidata id",
#         "value": "Q1551044",
#         "wiki_order": "211"
#       },
#       {
#         "data_type": "wikidata_label",
#         "label": "Wikidata label",
#         "value": "Alabama Agricultural and Mechanical University",
#         "wiki_order": "212"
#       },
#       {
#         "data_type": "wikidata_aliases",
#         "label": "Wikidata aliases",
#         "value": [
#           "Alabama Agricultural and Mechanical University",
#           "Alabama A&M University",
#           "AAMU",
#           "aamu.edu"
#         ],
#         "wiki_order": "213"
#       },
#       {
#         "data_type": "wiki_maps_trigger",
#         "value": "/local.js?&ha=1&lla=-86.568694444444,34.782611111111:0.1&heading=Alabama%20A%26M%20University&q=Alabama%20A%20%26%20M%20University%20wikipedia",
#         "wiki_order": 999
#       }
#     ],
#     "meta": [
#       {
#         "data_type": "string",
#         "label": "article_title",
#         "value": "Alabama A&M University"
#       },
#       {
#         "data_type": "string",
#         "label": "template_name",
#         "value": "infobox university"
#       },
#       {
#         "data_type": "string",
#         "label": "formatting_rules",
#         "value": "university"
#       }
#     ]
#   },
#   "OfficialDomain": "aamu.edu",
#   "OfficialWebsite": "https://www.aamu.edu",
#   "Redirect": "",
#   "RelatedTopics": [
#     {
#       "FirstURL": "https://duckduckgo.com/Alabama_Cooperative_Extension_System",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/Alabama_Cooperative_Extension_System\">Alabama Cooperative Extension System</a> - The Alabama Cooperative Extension System provides educational outreach to the citizens of Alabama on behalf of the state's two land grant universities: Alabama A&M University and Auburn University.",
#       "Text": "Alabama Cooperative Extension System - The Alabama Cooperative Extension System provides educational outreach to the citizens of Alabama on behalf of the state's two land grant universities: Alabama A&M University and Auburn University."
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/Magic_City_Classic",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/Magic_City_Classic\">Magic City Classic</a> - The Magic City Classic is an annual American football \"classic\" that features Alabama A&M University and Alabama State University, the two largest historically black universities in the state. It is played at Legion Field in Birmingham.",
#       "Text": "Magic City Classic - The Magic City Classic is an annual American football \"classic\" that features Alabama A&M University and Alabama State University, the two largest historically black universities in the state. It is played at Legion Field in Birmingham."
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/WJAB",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/WJAB\">WJAB 90.9 FM Radio</a> - WJAB is a National Public Radio-affiliated college radio station in Huntsville, Alabama. It primarily features jazz and blues music programming aimed toward African-American residents of the northern counties of Alabama and several counties in southern middle Tennessee.",
#       "Text": "WJAB 90.9 FM Radio - WJAB is a National Public Radio-affiliated college radio station in Huntsville, Alabama. It primarily features jazz and blues music programming aimed toward African-American residents of the northern counties of Alabama and several counties in southern middle Tennessee."
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/Alabama_Cooperative_Extension_System",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/Alabama_Cooperative_Extension_System\">Alabama Cooperative Extension System</a>",
#       "Text": "Alabama Cooperative Extension System"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/Historic_districts_in_Huntsville%2C_Alabama",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/Historic_districts_in_Huntsville%2C_Alabama\">Historic districts in Huntsville, Alabama</a>",
#       "Text": "Historic districts in Huntsville, Alabama"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/Universities_and_colleges_in_Huntsville%2C_Alabama",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/Universities_and_colleges_in_Huntsville%2C_Alabama\">Universities and colleges in Huntsville, Alabama</a>",
#       "Text": "Universities and colleges in Huntsville, Alabama"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/National_Register_of_Historic_Places_in_Huntsville%2C_Alabama",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/National_Register_of_Historic_Places_in_Huntsville%2C_Alabama\">National Register of Historic Places in Huntsville, Alabama</a>",
#       "Text": "National Register of Historic Places in Huntsville, Alabama"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/Land-grant_universities_and_colleges",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/Land-grant_universities_and_colleges\">Land-grant universities and colleges</a>",
#       "Text": "Land-grant universities and colleges"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/African-American_history_of_Alabama",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/African-American_history_of_Alabama\">African-American history of Alabama</a>",
#       "Text": "African-American history of Alabama"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/Historically_black_universities_and_colleges_in_the_United_States",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/Historically_black_universities_and_colleges_in_the_United_States\">Historically black universities and colleges in the United States</a>",
#       "Text": "Historically black universities and colleges in the United States"
#     },
#     {
#       "FirstURL": "https://duckduckgo.com/c/Properties_on_the_Alabama_Register_of_Landmarks_and_Heritage",
#       "Icon": {
#         "Height": "",
#         "URL": "",
#         "Width": ""
#       },
#       "Result": "<a href=\"https://duckduckgo.com/c/Properties_on_the_Alabama_Register_of_Landmarks_and_Heritage\">Properties on the Alabama Register of Landmarks and Heritage</a>",
#       "Text": "Properties on the Alabama Register of Landmarks and Heritage"
#     }
#   ],
#   "Results": [
#     {
#       "FirstURL": "https://www.aamu.edu",
#       "Icon": {
#         "Height": 16,
#         "URL": "/i/aamu.edu.ico",
#         "Width": 16
#       },
#       "Result": "<a href=\"https://www.aamu.edu\"><b>Official site</b></a><a href=\"https://www.aamu.edu\"></a>",
#       "Text": "Official site"
#     },
#     {
#       "FirstURL": "http://www.aamu.edu/",
#       "Icon": {
#         "Height": 16,
#         "URL": "/i/aamu.edu.ico",
#         "Width": 16
#       },
#       "Result": "<a href=\"http://www.aamu.edu/\"><b>Official site</b></a><a href=\"http://www.aamu.edu/\"> - Alabama A&M University</a>",
#       "Text": "Official site - Alabama A&M University"
#     }
#   ],
#   "Type": "A",
#   "meta": {
#     "attribution": null,
#     "blockgroup": null,
#     "created_date": null,
#     "description": "Wikipedia",
#     "designer": null,
#     "dev_date": null,
#     "dev_milestone": "live",
#     "developer": [
#       {
#         "name": "DDG Team",
#         "type": "ddg",
#         "url": "http://www.duckduckhack.com"
#       }
#     ],
#     "example_query": "nikola tesla",
#     "id": "wikipedia_fathead",
#     "is_stackexchange": null,
#     "js_callback_name": "wikipedia",
#     "live_date": null,
#     "maintainer": {
#       "github": "duckduckgo"
#     },
#     "name": "Wikipedia",
#     "perl_module": "DDG::Fathead::Wikipedia",
#     "producer": null,
#     "production_state": "online",
#     "repo": "fathead",
#     "signal_from": "wikipedia_fathead",
#     "src_domain": "en.wikipedia.org",
#     "src_id": 1,
#     "src_name": "Wikipedia",
#     "src_options": {
#       "directory": "",
#       "is_fanon": 0,
#       "is_mediawiki": 1,
#       "is_wikipedia": 1,
#       "language": "en",
#       "min_abstract_length": "20",
#       "skip_abstract": 0,
#       "skip_abstract_paren": 0,
#       "skip_end": "0",
#       "skip_icon": 0,
#       "skip_image_name": 0,
#       "skip_qr": "",
#       "source_skip": "",
#       "src_info": ""
#     },
#     "src_url": null,
#     "status": "live",
#     "tab": "About",
#     "topic": [
#       "productivity"
#     ],
#     "unsafe": 0
#   }
# }

import pandas as pd
import requests

# Load the DataFrame from the CSV file
df = pd.read_csv('new_universities_usa.csv')

# Define the extract_info function to parse JSON data
def extract_info(data):
    result = {"image": "", "url": ""}

    # Extract the image URL
    if "Image" in data and data["Image"]:
        result["image"] = "https://duckduckgo.com" + data["Image"]

    # Extract the official website URL from the Infobox content
    if "Infobox" in data:
        for item in data["Infobox"].get("content", []):
            if item.get("label") == "Official Website" and item.get("value"):
                result["url"] = item["value"]
                break  # Exit loop after finding the website

    return result

# List to store results
university_details = []

# Iterate over each URL in the search_url column
for url in df['search_url']:
    response = requests.get(url)
    if response.status_code == 200:
        json_data = response.json()
        print(30*"--")
        print(json_data)
        try:
            info = extract_info(json_data)  # Attempt to extract information
        except Exception as e:
            print(f"Error extracting data: {e}")  # Optionally print or log the error
            info = {"image": "", "url": ""}  # Use default empty values on error
        university_details.append(info)
    else:
        university_details.append({"image": "", "url": ""})
# Out:
# ------------------------------------------------------------
# ...

# %%
#next i want to extract the url from the website of the university  and the logo from the wiki page
print(university_details)
# Out:
# [{'image': 'https://duckduckgo.com/i/81907f4fe3655524.png', 'url': 'http://www.aamu.edu/'}, {'image': 'https://duckduckgo.com/i/82f153f9439196e9.png', 'url': 'http://www.uab.edu'}, {'image': 'https://duckduckgo.com/i/eaab7c16.png', 'url': 'https://www.amridgeuniversity.edu/'}, {'image': 'https://duckduckgo.com/i/4680d0bc.png', 'url': 'http://www.uah.edu'}, {'image': 'https://duckduckgo.com/i/6bf43681e4ccc6b4.png', 'url': 'http://www.alasu.edu'}, {'image': 'https://duckduckgo.com/i/00acdaa600c586c9.png', 'url': 'https://www.ua.edu/'}, {'image': 'https://duckduckgo.com/i/50aa2301.png', 'url': 'https://www.athens.edu/'}, {'image': 'https://duckduckgo.com/i/d0608dc4.png', 'url': 'http://www.aum.edu'}, {'image': 'https://duckduckgo.com/i/491cbec1.png', 'url': 'https://auburn.edu'}, {'image': 'https://duckduckgo.com/i/174e50c7e4418d10.png', 'url': ''}, {'image': '', 'url': 'http://www.ccal.edu/'}, {'image': 'https://duckduckgo.com/i/1e58c81b.png', 'url': 'http://www.faulkner.edu'}, {'image
# ...

# %%
import pandas as pd

# Load the existing CSV file into a DataFrame
df = pd.read_csv('new_universities_usa.csv')

# Assuming university_details is the list of dictionaries containing the "image" and "url" for each university
# Check if the length of university_details matches the number of rows in df
if len(university_details) == len(df):
    # Create new columns for 'image' and 'url'
    df['image'] = [detail['image'] for detail in university_details]
    df['url'] = [detail['url'] for detail in university_details]
else:
    print("Error: The number of entries in university_details does not match the number of rows in the DataFrame.")

# Save the updated DataFrame back to the CSV file
df.to_csv('new_universities_usa.csv', index=False)

# %%
#get shit from wikipedia hellop my name is and i am going to be in 
"""
first query:

search the internet and check if {university_name} has a wikipedia page. if yes return the link else False.

second query:

given the selenium content please return the url to the logo of the university if you think there is no logo available just return false.


should i just do the thing open source lmao? like a lil python package for this?

lets build this by myself really quick - can do this with oai function calling
"""
def get_search_results(query):
    """
    gets as input query like "What is the url of the wikipedia page of {university_name}"
    """
    #University of Alabama at Birmingham
    #http://api.duckduckgo.com/?q=University%20of%20Amridge%20wikipedia&format=json
    pass


def extract_url_and_logo_url(search_results):
    """
    gets as input the urls of search results and needs to return false or the wiki url of the wiki page
    """
    pass
# Out:
# {'Abstract': '', 'AbstractSource': '', 'AbstractText': '', 'AbstractURL': '', 'Answer': '', 'AnswerType': '', 'Definition': '', 'DefinitionSource': '', 'DefinitionURL': '', 'Entity': '', 'Heading': '', 'Image': '', 'ImageHeight': '', 'ImageIsLogo': '', 'ImageWidth': '', 'Infobox': '', 'Redirect': '', 'RelatedTopics': [], 'Results': [], 'Type': '', 'meta': {'attribution': None, 'blockgroup': None, 'created_date': '2021-03-24', 'description': 'testing', 'designer': None, 'dev_date': '2021-03-24', 'dev_milestone': 'development', 'developer': [{'name': 'zt', 'type': 'duck.co', 'url': 'https://duck.co/user/zt'}], 'example_query': '', 'id': 'just_another_test', 'is_stackexchange': 0, 'js_callback_name': 'another_test', 'live_date': None, 'maintainer': {'github': ''}, 'name': 'Just Another Test', 'perl_module': 'DDG::Lontail::AnotherTest', 'producer': None, 'production_state': 'offline', 'repo': 'fathead', 'signal_from': 'just_another_test', 'src_domain': 'how about there', 'src_id': None, 
# ...

# %%
#https://en.wikipedia.org/wiki/Amridge_University
#https://en.wikipedia.org/wiki/university_of_alabama_at_birmingham

#http://api.duckduckgo.com/?q=harvard%20university%20wikipedia&format=json
#/i/eaab7c16.png
#https://duckduckgo.com//i/30cb964091732843.png
