# %%
"""
1. make dataset with all important places in san francisco
2. generate ai images for all the addresses
3. collect normal images of this places
4. make selectione are where people can choose a mode - either default or cyberpunk mode
"""

# %%
import requests
from urllib.parse import quote

def get_places_in_city(city_name, access_token, limit=10):
    # URL-encode the city name
    encoded_city_name = quote(city_name)
    # Mapbox Geocoding API endpoint
    url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{encoded_city_name}.json"
    
    print("url:",url)
    # Parameters for the request
    params = {
        "access_token": access_token,
        "types": "neighborhood,locality",  # Include neighborhoods and other place types
        "limit": limit,
        "proximity": "-122.45753520681166,37.74883261714179",
        "country": "us",
        "bbox": "-122.74799,37.61043,-122.12581,37.88317"  # Bounding box for San Francisco
    }
    
    # Make the request
    response = requests.get(url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        print("data:", data)
        print(30*"-")
        places = []
        for feature in data["features"]:
            places.append({
                "name": feature["text"],
                "full_name": feature["place_name"],
                "type": feature["place_type"][0],
                "coordinates": feature["center"]
            })
        return places
    else:
        return f"Error: {response.status_code}"

# Usage
access_token = "pk.eyJ1IjoieWFjaHR5NjYiLCJhIjoiY2x4aTZndXJuMW8xdzJpcHJyYTFiMnl1cSJ9.BQezezawWYgnD6sBZMsvnw"
city_name = "San Francisco, CA"

results = get_places_in_city(city_name, access_token)
for place in results:
    print(f"{place['name']} ({place['type']}): {place['full_name']}")
# Out:
# url: https://api.mapbox.com/geocoding/v5/mapbox.places/San%20Francisco%2C%20CA.json
# ...

# %%
import requests
from urllib.parse import quote

def get_places_in_city(city_name, access_token, limit=30):
    # URL-encode the city name
    encoded_city_name = quote(city_name)
    # Mapbox Geocoding API endpoint
    url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{encoded_city_name}.json"
    
    print("url:", url)
    # Parameters for the request
    params = {
        "access_token": access_token,
        "types": "neighborhood,locality,poi",  # Include more place types
        "limit": limit,
        "proximity": "-122.45753520681166,37.74883261714179",
        "country": "us",
        "bbox": "-122.74799,37.61043,-122.12581,37.88317"  # Commented out bounding box for testing
    }
    
    # Make the request
    response = requests.get(url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        print("data:", data)
        print(30*"-")
        places = []
        for feature in data["features"]:
            places.append({
                "name": feature["text"],
                "full_name": feature["place_name"],
                "type": feature["place_type"][0],
                "coordinates": feature["center"]
            })
        return places
    else:
        return f"Error: {response.status_code}"

# Usage
access_token = "pk.eyJ1IjoieWFjaHR5NjYiLCJhIjoiY2x4aTZndXJuMW8xdzJpcHJyYTFiMnl1cSJ9.BQezezawWYgnD6sBZMsvnw"
city_name = "San Francisco, CA"

results = get_places_in_city(city_name, access_token)
for place in results:
    print(f"{place['name']} ({place['type']}): {place['full_name']}")
# Out:
# url: https://api.mapbox.com/geocoding/v5/mapbox.places/San%20Francisco%2C%20CA.json
# ...

# %%
import requests
from urllib.parse import quote
import time

def get_places_in_city(city_name, access_token, limit=10):
    # URL-encode the city name
    encoded_city_name = quote(city_name)
    # Mapbox Geocoding API endpoint
    url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{encoded_city_name}.json"
    
    # Define the bounding box for San Francisco
    min_lon, min_lat = -122.74799, 37.61043
    max_lon, max_lat = -122.12581, 37.88317
    
    # Calculate the step size for dividing the bounding box
    lon_step = (max_lon - min_lon) / 2
    lat_step = (max_lat - min_lat) / 2
    
    places = []
    
    # Iterate over the bounding box in smaller sections
    for i in range(2):
        for j in range(2):
            bbox = f"{min_lon + i * lon_step},{min_lat + j * lat_step},{min_lon + (i + 1) * lon_step},{min_lat + (j + 1) * lat_step}"
            print(f"Requesting bbox: {bbox}")
            
            # Parameters for the request
            params = {
                "access_token": access_token,
                "types": "neighborhood,locality,poi",  # Include more place types
                "limit": limit,
                "proximity": "-122.45753520681166,37.74883261714179",
                "country": "us",
                "bbox": bbox  # Bounding box for the current section
            }
            
            # Make the request
            response = requests.get(url, params=params)
            
            # Check if the request was successful
            if response.status_code == 200:
                data = response.json()
                print("data:", data)
                print(30*"-")
                for feature in data["features"]:
                    place = {
                        "name": feature["text"],
                        "full_name": feature["place_name"],
                        "type": feature["place_type"][0],
                        "coordinates": feature["center"]
                    }
                    places.append(place)
                    # Print place details immediately
                    print(f"{place['name']} ({place['type']}): {place['full_name']}")
            else:
                print(f"Error: {response.status_code}")
            
            # Wait for 5 seconds before the next request
            time.sleep(5)
    
    return places

# Usage
access_token = "pk.eyJ1IjoieWFjaHR5NjYiLCJhIjoiY2x4aTZndXJuMW8xdzJpcHJyYTFiMnl1cSJ9.BQezezawWYgnD6sBZMsvnw"
city_name = "San Francisco, CA"

results = get_places_in_city(city_name, access_token)
# Out:
# Requesting bbox: -122.74799,37.61043,-122.43690000000001,37.7468
# ...

# %%
import requests
from urllib.parse import quote
import time

def get_places_in_city(city_name, access_token, limit=10):
    # URL-encode the city name
    encoded_city_name = quote(city_name)
    # Mapbox Geocoding API endpoint
    url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{encoded_city_name}.json"
    
    # Define the bounding box for San Francisco
    min_lon, min_lat = -122.74799, 37.61043
    max_lon, max_lat = -122.12581, 37.88317
    
    # Calculate the step size for dividing the bounding box
    lon_step = (max_lon - min_lon) / 40
    lat_step = (max_lat - min_lat) / 40
    
    places = []
    
    # Iterate over the bounding box in smaller sections
    for i in range(40):
        for j in range(40):
            bbox = f"{min_lon + i * lon_step},{min_lat + j * lat_step},{min_lon + (i + 1) * lon_step},{min_lat + (j + 1) * lat_step}"
            print(f"Requesting bbox: {bbox}")
            
            # Parameters for the request
            params = {
                "access_token": access_token,
                "types": "neighborhood,locality,poi",  # Include more place types
                "limit": limit,
                "proximity": "-122.45753520681166,37.74883261714179",
                "country": "us",
                "bbox": bbox  # Bounding box for the current section
            }
            
            # Make the request
            response = requests.get(url, params=params)
            
            # Check if the request was successful
            if response.status_code == 200:
                data = response.json()
                print("data:", data)
                print(30*"-")
                if len(data["features"]) >= limit:
                    print("Response contains 10 or more features, stopping further requests.")
                    for feature in data["features"]:
                        place = {
                            "name": feature["text"],
                            "full_name": feature["place_name"],
                            "type": feature["place_type"][0],
                            "coordinates": feature["center"]
                        }
                        places.append(place)
                        # Print place details immediately
                        print(f"{place['name']} ({place['type']}): {place['full_name']}")
                    return places
                for feature in data["features"]:
                    place = {
                        "name": feature["text"],
                        "full_name": feature["place_name"],
                        "type": feature["place_type"][0],
                        "coordinates": feature["center"]
                    }
                    places.append(place)
                    # Print place details immediately
                    print(f"{place['name']} ({place['type']}): {place['full_name']}")
            else:
                print(f"Error: {response.status_code}")
            
            # Wait for 5 seconds before the next request
            #time.sleep(5)
    
    return places

# Usage
access_token = "pk.eyJ1IjoieWFjaHR5NjYiLCJhIjoiY2x4aTZndXJuMW8xdzJpcHJyYTFiMnl1cSJ9.BQezezawWYgnD6sBZMsvnw"
city_name = "San Francisco, CA"

results = get_places_in_city(city_name, access_token)
# Out:
# Requesting bbox: -122.74799,37.61043,-122.73243550000001,37.6172485
# data: {'type': 'FeatureCollection', 'query': ['san', 'francisco', 'ca'], 'features': [], 'attribution': 'NOTICE: © 2024 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}
# ------------------------------
# Requesting bbox: -122.74799,37.6172485,-122.73243550000001,37.624067000000004
# data: {'type': 'FeatureCollection', 'query': ['san', 'francisco', 'ca'], 'features': [], 'attribution': 'NOTICE: © 2024 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}
# ------------------------------
# ...

# %%
"""
what is the limit for the requests i can do?
"""
from openai import OpenAI
import os 
import time
import requests

openai_api_key = os.environ.get("OPENAI_API_KEY")
client = OpenAI(api_key=openai_api_key)

# Function to generate and save an image
def generate_and_save_image(prompt):
    response = client.images.generate(
        model="dall-e-3",
        prompt=prompt + " San Francisco in Cyberpunk style.",
        size="1024x1024",
        quality="standard",
        n=1,
    )

    image_url = response.data[0].url
    print(image_url)

    # Download the image
    image_response = requests.get(image_url)

    # Save the image to the images folder with a name based on the prompt
    image_name = f"{prompt.replace(' ', '_')}.png"
    image_path = os.path.join("images", image_name)
    with open(image_path, "wb") as f:
        f.write(image_response.content)

    print(f"Image saved to {image_path}")

# Read all lines from the text file
with open("all", "r") as file:
    lines = file.readlines()

# Create the images folder if it doesn't exist
os.makedirs("images", exist_ok=True)

# Process each line one by one
for line in lines:
    prompt = line.strip()  # Remove any leading/trailing whitespace
    if not prompt:
        continue  # Skip empty lines

    try:
        generate_and_save_image(prompt)
    except Exception as e:
        print(f"Error generating image: {e}")
    time.sleep(6)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-HWE1HKa9yeL1oDimdzMkEWLJ/user-H3ngVi2YMXtZlVerG4LADrpa/img-wUJ69trKXM0M3IRQn0LwV1x2.png?st=2024-07-07T01%3A50%3A48Z&se=2024-07-07T03%3A50%3A48Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-06T22%3A05%3A55Z&ske=2024-07-07T22%3A05%3A55Z&sks=b&skv=2023-11-03&sig=slJg5K/UFJt3ZIpKRPc8E9uhKR6pvEN7hprKF3wZTQ4%3D
# Image saved to images/Golden_Gate_Bridge.png
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-HWE1HKa9yeL1oDimdzMkEWLJ/user-H3ngVi2YMXtZlVerG4LADrpa/img-ald9v5Pz81dabmmoq7gVWpIS.png?st=2024-07-07T01%3A51%3A04Z&se=2024-07-07T03%3A51%3A04Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-06T07%3A19%3A13Z&ske=2024-07-07T07%3A19%3A13Z&sks=b&skv=2023-11-03&sig=Q8xcF5I22M2fPmB9z3cdZY813KwTY91baMz%2B8yWqDjs%3D
# ...

# %%
import requests
from urllib.parse import quote

def get_coordinates(place_name, access_token):
    # URL-encode the place name
    encoded_place_name = quote(place_name)
    # Mapbox Geocoding API endpoint
    url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{encoded_place_name}.json"
    
    # Parameters for the request
    params = {
        "access_token": access_token,
        "limit": 1,  # We only need the top result
        "proximity": "-122.4194,37.7749",  # Centered around San Francisco
        "country": "us"
    }
    
    # Make the request
    response = requests.get(url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        if data["features"]:
            feature = data["features"][0]
            coordinates = feature["center"]
            return coordinates
        else:
            return None
    else:
        return None

# Usage
access_token = "pk.eyJ1IjoieWFjaHR5NjYiLCJhIjoiY2x4aTZndXJuMW8xdzJpcHJyYTFiMnl1cSJ9.BQezezawWYgnD6sBZMsvnw"
place_name = "Alamo Square, San Francisco, CA"

coordinates = get_coordinates(place_name, access_token)
if coordinates:
    print(f"Coordinates for {place_name}: {coordinates}")
else:
    print(f"Could not find coordinates for {place_name}")
# Out:
# Coordinates for Alamo Square, San Francisco, CA: [-122.43460275000001, 37.776252]

# %%
#next i want to find a good prompt for generating a cyberpunk like image 
#can e
